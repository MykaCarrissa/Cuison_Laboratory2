# %% [markdown]
# <a href="https://colab.research.google.com/github/MykaCarrissa/Cuison_Laboratory2/blob/main/Cuison_FinalPracticalExam_Elective2_4B_NS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-118255b3-14dc-4473-b75a-0e97d33be863" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-118255b3-14dc-4473-b75a-0e97d33be863">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(cdf)
# Out:
#       GENERAL APPEARANCE  ...  CLASS
# 0                      3  ...      0
# 1                      3  ...      0
# 2                      3  ...      0
# 3                      3  ...      0
# 4                      3  ...      0
# 5                      2  ...      0
# 6                      3  ...      0
# 7                      2  ...      0
# 8                      2  ...      0
# 9                      2  ...      0
# 10                     2  ...      0
# 11                     2  ...      0
# 12                     2  ...      0
# 13                     2  ...      0
# 14                     2  ...      0
# 15                     2  ...      0
# 16                     2  ...      0
# 17                     2  ...      0
# 18                     2  ...      0
# 19                     2  ...      0
# 20                     2  ...      0
# 21                     2  ...      0
# 22                     2  ...      0
# 23                     2  ...      0
# ...

# %%
cdf = pd.read_csv("Employability_sample.csv")
cdf.head()
# Out:
#    GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0                   3                   3                   3
# 1                   3                   3                   3
# 2                   3                   3                   3
# 3                   3                   3                   3
# 4                   3                   3                   3
#
#    MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# 0                 3                3                         2
# 1                 3                3                         2
# 2                 3                3                         2
# 3                 3                3                         2
# 4                 3                3                         2
#
#    COMMUNICATION SKILLS  Student Performance Rating  CLASS
# 0                     2                        60.0      0
# 1                     2                        60.0      0
# ...

# %%
cdf.head(500)
# Out:
#      GENERAL APPEARANCE  ...  CLASS
# 0                     3  ...      0
# 1                     3  ...      0
# 2                     3  ...      0
# 3                     3  ...      0
# 4                     3  ...      0
# 5                     2  ...      0
# 6                     3  ...      0
# 7                     2  ...      0
# 8                     2  ...      0
# 9                     2  ...      0
# 10                    2  ...      0
# 11                    2  ...      0
# 12                    2  ...      0
# 13                    2  ...      0
# 14                    2  ...      0
# 15                    2  ...      0
# 16                    2  ...      0
# 17                    2  ...      0
# 18                    2  ...      0
# 19                    2  ...      0
# 20                    2  ...      0
# 21                    2  ...      0
# 22                    2  ...      0
# 23                    2  ...      0
# 24                    2  ...      0
# ...

# %%
cdf.tail(100)
# Out:
#       GENERAL APPEARANCE  ...  CLASS
# 2882                   5  ...      1
# 2883                   5  ...      1
# 2884                   5  ...      1
# 2885                   5  ...      1
# 2886                   4  ...      1
# 2887                   4  ...      1
# 2888                   3  ...      1
# 2889                   4  ...      1
# 2890                   3  ...      1
# 2891                   5  ...      1
# 2892                   4  ...      1
# 2893                   4  ...      1
# 2894                   4  ...      1
# 2895                   3  ...      1
# 2896                   3  ...      1
# 2897                   5  ...      1
# 2898                   4  ...      1
# 2899                   4  ...      1
# 2900                   4  ...      1
# 2901                   4  ...      1
# 2902                   3  ...      1
# 2903                   4  ...      1
# 2904                   4  ...      1
# 2905                   5  ...      1
# ...

# %%
cdf.describe()
# Out:
#        GENERAL APPEARANCE  ...        CLASS
# count         2982.000000  ...  2982.000000
# mean             3.891683  ...     0.781690
# std              1.044147  ...     0.413168
# min              2.000000  ...     0.000000
# 25%              3.000000  ...     1.000000
# 50%              4.000000  ...     1.000000
# 75%              5.000000  ...     1.000000
# max              5.000000  ...     1.000000
#
# [8 rows x 9 columns]

# %%
df_dropped = cdf.drop(columns = ['Student Performance Rating'])
df_dropped[:10]
# Out:
#    GENERAL APPEARANCE  ...  CLASS
# 0                   3  ...      0
# 1                   3  ...      0
# 2                   3  ...      0
# 3                   3  ...      0
# 4                   3  ...      0
# 5                   2  ...      0
# 6                   3  ...      0
# 7                   2  ...      0
# 8                   2  ...      0
# 9                   2  ...      0
#
# [10 rows x 8 columns]

# %%
cdf.dtypes
# Out:
# GENERAL APPEARANCE              int64
# MANNER OF SPEAKING              int64
# PHYSICAL CONDITION              int64
# MENTAL ALERTNESS                int64
# SELF-CONFIDENCE                 int64
# ABILITY TO PRESENT IDEAS        int64
# COMMUNICATION SKILLS            int64
# Student Performance Rating    float64
# CLASS                           int64
# dtype: object

# %%
mean = cdf[["GENERAL APPEARANCE","MANNER OF SPEAKING","PHYSICAL CONDITION","MENTAL ALERTNESS","SELF-CONFIDENCE","ABILITY TO PRESENT IDEAS","COMMUNICATION SKILLS","CLASS"]].mean()
print(mean)
# Out:
# GENERAL APPEARANCE          3.891683
# MANNER OF SPEAKING          3.767606
# PHYSICAL CONDITION          3.674044
# MENTAL ALERTNESS            3.833333
# SELF-CONFIDENCE             3.910463
# ABILITY TO PRESENT IDEAS    3.693830
# COMMUNICATION SKILLS        3.294098
# CLASS                       0.781690
# dtype: float64

# %%
med = cdf[["GENERAL APPEARANCE","MANNER OF SPEAKING","PHYSICAL CONDITION","MENTAL ALERTNESS","SELF-CONFIDENCE","ABILITY TO PRESENT IDEAS","COMMUNICATION SKILLS","CLASS"]].median()
print(med)
# Out:
# GENERAL APPEARANCE          4.0
# MANNER OF SPEAKING          4.0
# PHYSICAL CONDITION          4.0
# MENTAL ALERTNESS            4.0
# SELF-CONFIDENCE             4.0
# ABILITY TO PRESENT IDEAS    4.0
# COMMUNICATION SKILLS        3.0
# CLASS                       1.0
# dtype: float64

# %%
min(cdf), max(cdf)
# Out:
# ('ABILITY TO PRESENT IDEAS', 'Student Performance Rating')

# %%
cdf.std()
# Out:
# GENERAL APPEARANCE            1.044147
# MANNER OF SPEAKING            0.769677
# PHYSICAL CONDITION            1.009045
# MENTAL ALERTNESS              0.810069
# SELF-CONFIDENCE               0.807773
# ABILITY TO PRESENT IDEAS      0.755937
# COMMUNICATION SKILLS          0.891474
# Student Performance Rating    7.672066
# CLASS                         0.413168
# dtype: float64

# %%
cdf.count()
# Out:
# GENERAL APPEARANCE            2982
# MANNER OF SPEAKING            2982
# PHYSICAL CONDITION            2982
# MENTAL ALERTNESS              2982
# SELF-CONFIDENCE               2982
# ABILITY TO PRESENT IDEAS      2982
# COMMUNICATION SKILLS          2982
# Student Performance Rating    2982
# CLASS                         2982
# dtype: int64

# %%
q = np.percentile(cdf,[25,50,75])
print(q)
# Out:
# [3. 4. 5.]

# %%
ax = cdf['GENERAL APPEARANCE'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['MANNER OF SPEAKING'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['PHYSICAL CONDITION'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['MENTAL ALERTNESS'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['SELF-CONFIDENCE'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['ABILITY TO PRESENT IDEAS'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['COMMUNICATION SKILLS'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
ax = cdf['CLASS'].value_counts().plot(kind='bar', figsize=(10,10))

# %%
plt.scatter(x=cdf['GENERAL APPEARANCE'], y=cdf['MANNER OF SPEAKING'])

# %%
plt.scatter(x=cdf['GENERAL APPEARANCE'], y=cdf['MANNER OF SPEAKING'])
plt.xlabel("Weight")
plt.ylabel("Weight") 
plt.title("Scatter Plot of Height & Weight") 
plt.tight_layout() 
plt.show()

# %%
plt.scatter(x=cdf['PHYSICAL CONDITION'], y=cdf['MENTAL ALERTNESS'])
plt.xlabel("Weight")
plt.ylabel("Weight") 
plt.title("Scatter Plot of Height & Weight") 
plt.tight_layout() 
plt.show()

# %%
plt.scatter(x=cdf['SELF-CONFIDENCE'], y=cdf['ABILITY TO PRESENT IDEAS'])
plt.xlabel("Weight")
plt.ylabel("Weight") 
plt.title("Scatter Plot of Height & Weight") 
plt.tight_layout() 
plt.show()

# %%
plt.scatter(x=cdf['COMMUNICATION SKILLS'], y=cdf['CLASS'])
plt.xlabel("Weight")
plt.ylabel("Weight") 
plt.title("Scatter Plot of Height & Weight") 
plt.tight_layout() 
plt.show()

# %%
sns.distplot(cdf['GENERAL APPEARANCE'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['MANNER OF SPEAKING'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['PHYSICAL CONDITION'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['MENTAL ALERTNESS'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['SELF-CONFIDENCE'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['ABILITY TO PRESENT IDEAS'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['COMMUNICATION SKILLS'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(cdf['CLASS'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
